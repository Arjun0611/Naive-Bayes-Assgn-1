# %%
#Q1.

# %%
# Bayes' theorem is a fundamental concept in probability theory.
# Its purpose is to calculate the probability of an event A given evidence B.
# Involves conditional probabilities and the probability of evidence.

# %%
# Q2.

# %%
# P(A|B) = (P(B|A) * P(A))/P(B)
# P(A|B): The probability of event A occuring given that event B has occurred.
# P(B|A): The probability of event B occuring given that event A has occurred.
# P(A) and P(B): The probabilities of events A and B occurring independently.

# %%
#Q3.

# %%
#Classification: Used in machine learning for probabilistic classification.
#Medical Diagnosis: Assesses probability of a disease given symptoms.
#Spam Filtering: Determines likelihood of an email being spam based on content.
#Risk Assessment: Evaluates probabilities in decision-making under uncertainty.
#Natural Language Processing: Applied to language models for better predictions.
#Scientific Research: Analyzes and updates hypotheses with new data.
#Finance: Estimates probabilities in risk management and portfolio optimization.
#A/B Testing: Evaluates statistical significance in experiments.
#Legal Decision Making: Analyzes evidence in legal cases for likelihood of guilt or innocence.

# %%
#Q4.

#Foundation: Bayes' theorem is based on conditional probability.
#Conditional Probability: Describes the probability of an event given another.
#Incorporation in Bayes' Theorem: Utilizes conditional probability to update prior beliefs.
#Posterior Probability: Result of applying Bayes' theorem is a posterior probability.
#Event Dependence: Illustrates how the probability of an event changes based on new information.
#Sequential Update: Bayes' theorem allows sequential updating of probabilities with additional data.
#Key Formula: Expresses the relationship mathematically in terms of probabilities.

# %%
#Q5.

#Multinomial Naive Bayes: Suitable for discrete features, often used in text classification.
#Gaussian Naive Bayes: Appropriate for continuous features, assumes a Gaussian distribution.
#Bernoulli Naive Bayes: Applicable for binary features, common in document classification.

# %%
#Q6.

# %% [markdown]
# ![thumbnail_IMG-0117.jpg](attachment:90608c1f-3349-478a-a7ff-cb2f3d24efc2.jpg)
